# %% [markdown]
# ### Clean the previous plot

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.colors import ListedColormap
from upsetplot import UpSet, from_contents
import seaborn as sns
from matplotlib_venn import venn2
plt.rcParams['svg.fonttype'] = 'none'
from matplotlib.patches import Patch

# %%
sns.set_theme(font_scale=1.4, style='whitegrid')

# %%
df = pd.read_csv('../Data/Network_GRN_HIVE_curated.txt', sep='\t')

# %%
# Count nodes
tf_nodes = set(df["tf.name"])
target_nodes = set(df["target.name"])
genes = target_nodes - tf_nodes  # Targets that are NOT TFs

node_counts = pd.DataFrame({
    "Category": "Nodes",
    "Type": ["Gene", "Tf"],
    "Count": [len(genes), len(tf_nodes)]
})

# Count edges (without splitting evidence)
edge_counts = df["reg.evidence"].value_counts().reset_index()
edge_counts.columns = ["Type", "Count"]
edge_counts["Category"] = "Edges"

# Combine for plotting
plot_df = pd.concat([node_counts, edge_counts])

colors = {'Tf':'purple', 'Gene':'green', 'motif, motif_CE':'lightgrey', 'FunTFBS, motif, motif_CE':'dimgrey','FunTFBS, motif':'darkgrey'}

# Define category positions
category_positions = {"Nodes": 0, "Edges": 0.5}  # Reduce spacing

fig, ax = plt.subplots(figsize=(6, 5))

bottoms = {"Nodes": 0, "Edges": 0}

for _, row in plot_df.iterrows():
    color = colors.get(row["Type"], "gray")
    ax.bar(
        category_positions[row["Category"]], row["Count"], label=row["Type"],
        bottom=bottoms[row["Category"]], color=color, width=0.1,  # Adjust width
    )
    bottoms[row["Category"]] += row["Count"]

# Set category labels at custom positions
ax.set_xticks([category_positions["Nodes"], category_positions["Edges"]])
ax.set_xticklabels(["Nodes", "Edges"], fontsize=20)
ax.set_ylabel("Count", fontsize=20)
ax.tick_params(axis='y', labelsize=20)
ax.spines.top.set_visible(False)
ax.spines.right.set_visible(False)


# Ensure only unique legend entries
handles, labels = ax.get_legend_handles_labels()
unique_labels = dict(zip(labels, handles))
ax.legend(unique_labels.values(), unique_labels.keys(), title="Type", loc="upper left", bbox_to_anchor=(1, 1), fontsize=18, title_fontsize=20)

plt.savefig('./Fig2_A.svg', bbox_inches='tight', format='svg')
plt.show()

# %%
pd.concat([df['tf.name'], df['target.name']]).unique().shape
# Out:
# (1786,)

# %%
df['reg.evidence'].value_counts()
# Out:
# reg.evidence
# motif, motif_CE             3127
# FunTFBS, motif, motif_CE     608
# FunTFBS, motif               466
# Name: count, dtype: int64

# %%
# # Count TFs and Targets separately
# tf_count = df['tf.name'].nunique()
# target_count = df[~df['target.name'].isin(df['tf.name'])]['target.name'].nunique()

# # Count edges by evidence
# evidence_counts = df['reg.evidence'].str.split(', ').explode().value_counts()

# # Categories
# categories = ['Nodes', 'Edges']

# # Subcategories (TFs, Targets for Nodes; Evidence Types for Edges)
# node_subcategories = ['TFs', 'Targets']
# edge_subcategories = list(evidence_counts.index)

# # Values
# node_values = [tf_count, target_count]
# edge_values = list(evidence_counts.values)

# # Plot setup
# fig, ax = plt.subplots(figsize=(8, 6))

# # Stacking bars
# bottom_nodes = 0  # Initial bottom position for stacking
# for subcat, value in zip(node_subcategories, node_values):
#     ax.bar('Nodes', value, label=subcat, bottom=bottom_nodes, color=['red', 'blue'][node_subcategories.index(subcat)])
#     bottom_nodes += value

# bottom_edges = 0  # Initial bottom position for stacking edges
# colors = ['lightgreen', 'green', 'darkgreen']  # Adjust colors for different evidence types

# for subcat, value, color in zip(edge_subcategories, edge_values, colors[:len(edge_values)]):
#     ax.bar('Edges', value, label=subcat, bottom=bottom_edges, color=color)
#     bottom_edges += value

# # Labels and title
# ax.set_ylabel('Count')
# ax.set_title('Number of Nodes (by TFs & Targets) and Edges (by Evidence Type) in the cGRN')

# # Legend outside
# ax.legend(title='Type', bbox_to_anchor=(1.05, 1), loc='upper left')

# # Show plot
# plt.tight_layout()
# plt.show()

# %%
info = pd.read_csv('../Results_hubs_activity_stats_shuffle_corrected.tsv',sep='\t')
info = info.rename(columns={'gene.family':'Family'})
info_index = info.set_index('OLN')
net = pd.read_csv('../Data/Network_GRN_HIVE_curated.txt',sep='\t')
TFs = net['tf.name'].unique()
Tf_info = info_index.loc[TFs]
signif_tf = Tf_info[~Tf_info['Groups_corrected'].isna()]

# %%
import hashlib
# Generate 25 distinct colors
colors = plt.cm.tab20b.colors

# Take the first 25 distinct colors
colors = colors[:Tf_info['Family'].nunique()]

# Create a colormap with the 25 distinct colors
custom_cmap = ListedColormap(colors)

# %%
import distinctipy
# Get unique families
unique_families = Tf_info['Family'].unique()

# Generate maximally distinct colors
num_families = len(unique_families)
colors = distinctipy.get_colors(num_families)

# Create a dictionary mapping each family to a unique color
family_color_dict = {family: color for family, color in zip(unique_families, colors)}

# %%
import matplotlib.colors as mcolors
named_colors = mcolors.CSS4_COLORS
named_colors_rgba = {
    name: mcolors.to_rgba(hex_color)
    for name, hex_color in named_colors.items()
}

# %%
print(named_colors_rgba["lawngreen"])
# Out:
# (0.48627450980392156, 0.9882352941176471, 0.0, 1.0)

# %%
unique_families_significant = signif_tf['Family'].unique()

custom_family_colors = {
    'bZIP': (0.121, 0.466, 0.705),
    'bHLH': (0.333, 0.420, 0.184),
    'ARF': (0.172, 0.627, 0.172),
    'ERF': (1.000, 0.498, 0.054),
    'NAC': (0.580, 0.404, 0.741),
    'Dof': (0.545, 0.271, 0.075),
    'MYB': (0.890, 0.467, 0.761),
    'HSF': (0.839, 0.153, 0.157),
    'E2F/DP': (0.486, 0.988, 0),
    'MYB_related': (0.529, 0.808, 0.922),
    'WRKY': (0.3, 0.3, 0.9),
    'TCP': (0.737, 0.561, 0.561),
    'GATA': (0.7, 0.2, 0.9),
    'CPP': (1.000, 0.843, 0)
}

family_color_dict = {
    fam: custom_family_colors[fam]
    for fam in unique_families_significant
    if fam in custom_family_colors
}

default_grey = (0.85, 0.85, 0.85)

all_families = Tf_info['Family'].unique()

extended_family_color_dict = {
    family: family_color_dict.get(family, default_grey)
    for family in all_families
}

# %%
# # Grouping the dataframe by community and transcription factor family
# grouped_df = signif_tf.groupby(['Community', 'Family']).size().unstack(fill_value=0)
# # Count the occurrences of each TF family
# family_counts = signif_tf['Family'].value_counts().sort_values(ascending=False)

# # Ensure colors match the sorted order
# sorted_families = family_counts.index  # Get TF families in sorted order
# sorted_colors = [extended_family_color_dict[family] for family in sorted_families]


# # Plot the histogram
# plt.figure(figsize=(20, 12))
# family_counts.plot(kind='bar', color=sorted_colors)

# ax = plt.gca()
# ax.spines.top.set_visible(False)
# ax.spines.right.set_visible(False)

# plt.xlabel('Transcription Factor Family', fontsize = 20)
# plt.ylabel('Number of regulator Transcription Factors', fontsize = 20)
# plt.yticks(fontsize = 18)
# plt.xticks(rotation=45, ha='right', fontsize = 18) # Rotate x-axis labels for better readability
# plt.tight_layout()
# # plt.savefig('./Results/Clean_plot/TF_family_significant_TF.png')
# plt.show()

# %%
# # Grouping the DataFrame by community and transcription factor family
# grouped_df = Tf_info.groupby(['Community', 'Family']).size().unstack(fill_value=0)

# # Generate unique colors based on entity names
# # color_dict = {entity: colors[i % len(colors)] for i, entity in enumerate(grouped_df.columns)}
# # Count the occurrences of each TF family
# family_counts = Tf_info['Family'].value_counts().sort_values(ascending=False)

# # Ensure colors match the sorted order
# sorted_families = family_counts.index  # Get TF families in sorted order
# sorted_colors = [extended_family_color_dict[family] for family in sorted_families]

# # Plot the histogram
# plt.figure(figsize=(10, 6))
# family_counts.plot(kind='bar', color=sorted_colors)
# plt.title('Regulator Transcription Factor Families in the network')
# plt.xlabel('Transcription Factor Family')
# plt.ylabel('Number of regulator Transcription Factors')
# plt.xticks(rotation=45, ha='right')  # Rotate x-axis labels for better readability
# plt.tight_layout()
# # plt.savefig('./Results/Plot/TF_family_all_reg_TF.svg', format='svg')
# plt.show()

# %%
# Count all TF family occurrences (general dataset)
general_family_counts = Tf_info['Family'].value_counts()

# Count only significant TF occurrences
significant_family_counts = signif_tf['Family'].value_counts()

# Sort families by total count (general) to define order
sorted_families = general_family_counts.sort_values(ascending=False).index

# Align significant counts to this order, fill missing values with 0
significant_family_counts = significant_family_counts.reindex(sorted_families, fill_value=0)

# Align general counts (already sorted)
general_family_counts = general_family_counts.reindex(sorted_families)

# Ensure colors match sorted families
sorted_colors = [extended_family_color_dict[family] for family in sorted_families]

# Create the butterfly plot
fig, ax = plt.subplots(figsize=(20, 12))

# Left side: General TF families (plotted as negative but displayed as positive)
ax.barh(sorted_families, -general_family_counts, color=sorted_colors, label="All Regulator TF Families")

# Right side: Significant TF families (plotted normally)
ax.barh(sorted_families, significant_family_counts, color=sorted_colors, label="Significant Regulator TF Families")

# Formatting
ax.set_xlabel("Number of Regulator Transcription Factor", fontsize=20)
ax.set_ylabel("Transcription Factor Family", fontsize=20)
ax.axvline(0, color='black', linewidth=1)  # Vertical line at center

# Add section titles
ax.text(-general_family_counts.max() * 0.7, len(sorted_families) + 0.2, "General TF Families", 
        fontsize=18, fontweight="bold", ha="center")
ax.text(significant_family_counts.max() * 0.7, len(sorted_families) + 0.2, "Significant TF Families", 
        fontsize=18, fontweight="bold", ha="center")

# Adjust x-axis labels to display positive values
xticks = ax.get_xticks()
ax.set_xticklabels([str(abs(int(x))) for x in xticks], fontsize = 18)
ax.set_yticklabels(ax.get_yticklabels(), fontsize = 18)

ax.spines.top.set_visible(False)
ax.spines.right.set_visible(False)

plt.gca().invert_yaxis()  # Keep highest count at top
plt.tight_layout()
plt.savefig('./Fig3_A.svg', format='svg')
plt.show()
# Out:
# /tmp/ipykernel_92731/3152739262.py:41: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels([str(abs(int(x))) for x in xticks], fontsize = 18)
# /tmp/ipykernel_92731/3152739262.py:42: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_yticklabels(ax.get_yticklabels(), fontsize = 18)

# %%
# Remove zero-count families
tf_counts = significant_family_counts[significant_family_counts > 0]
tf_counts = tf_counts.sort_values(ascending=False)
# All wedges grey
colors = [extended_family_color_dict[tf] for tf in tf_counts.index]

# Calculate percentages
percentages = tf_counts / tf_counts.sum() * 100

# Create donut chart
fig, ax = plt.subplots(figsize=(10, 10))
wedges, _ = ax.pie(
    tf_counts,
    colors=colors,
    startangle=140,
    wedgeprops=dict(width=0.4)
)

# Draw center circle
centre_circle = plt.Circle((0, 0), 0.70, fc='white')
fig.gca().add_artist(centre_circle)

# Equal aspect ratio ensures pie is a circle
ax.axis('equal')  

# Add family names and percentages inside slices
for i, wedge in enumerate(wedges):
    angle = (wedge.theta2 + wedge.theta1) / 2.
    x = 0.75 * np.cos(np.deg2rad(angle))
    y = 0.75 * np.sin(np.deg2rad(angle))
    
    # If slice big enough, display label and percentage
    if wedge.theta2 - wedge.theta1 > 8:  # tweak threshold as needed
        label = f"{tf_counts.index[i]}\n({tf_counts.iloc[i]})"
        ax.text(
            x, y,
            label,
            ha='center', va='center',
            fontsize=11, color='white'
        )

plt.title("Transcription Factor Family Distribution", fontsize=20)

# Save and show
plt.tight_layout()
plt.savefig('./TF_family_significant_donut_.svg', format='svg')
plt.show()

# %%
tf_counts = significant_family_counts[significant_family_counts > 0]
tf_counts = tf_counts.sort_values(ascending=False)
# Create color list in order
colors = [extended_family_color_dict[tf] for tf in tf_counts.index]

# Plot
fig, ax = plt.subplots(figsize=(12, 2))

left = 0
for i, (tf, count) in enumerate(tf_counts.items()):
    ax.barh(0, count, left=left, color=colors[i], edgecolor='black')
    ax.text(left + count / 2, 0, f"{tf}\n({count})", ha='center', va='center', fontsize=9, color='white')
    left += count

# Remove axes and adjust
ax.set_xlim(0, tf_counts.sum())
ax.set_ylim(-0.5, 0.5)
ax.axis('off')

plt.title("Transcription Factor Family Distribution (Stacked Bar)", fontsize=16)
plt.tight_layout()
plt.savefig('./TF_family_significant_stacked_bar.svg', format='svg')
plt.show()

# %%
upsetplot_data = Tf_info.reset_index()
upsetplot_data = upsetplot_data[~upsetplot_data['Groups_corrected'].isna()]
upsetplot_data_only_activity = upsetplot_data[['OLN','Groups_corrected']]
upsetplot_data_only_activity['Groups_corrected'] = upsetplot_data_only_activity['Groups_corrected'].str.replace('_pval','', regex=False)
upsetplot_data_only_activity['Groups_corrected'] = upsetplot_data_only_activity['Groups_corrected'].str.split(' & ')
group_dict_only_acts = {}
for _, row in upsetplot_data_only_activity.iterrows():
    for group in row['Groups_corrected']:
        if group not in group_dict_only_acts:
            group_dict_only_acts[group] = []
        group_dict_only_acts[group].append(row['OLN'])
# Generate the from_contents DataFrame
upset_data = from_contents(group_dict_only_acts)
family_tf = Tf_info['Family']
upset_data = pd.merge(upset_data, family_tf, left_on=['id'], right_index=True)
# Create the UpSet plot
upset = UpSet(upset_data,  sort_by='-degree', intersection_plot_elements=0)
upset.style_categories(
    ["Mincognita_7dpi", "Mincognita_14dpi"], bar_facecolor="sienna")
upset.style_categories(
    ["PSTVd_M", "PSTVd_S23"], bar_facecolor="salmon")
upset.style_categories(
    ["Bcinerea", "Cfulvum"], bar_facecolor="darkolivegreen")
upset.style_categories(
    ["Pinfestans"], bar_facecolor="lawngreen")
upset.add_stacked_bars(by='Family', colors=extended_family_color_dict, elements=5)

# Plot the UpSet plot
plot = upset.plot()
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left',title='TF Family', title_fontsize=18, fontsize=14)    
plt.savefig('./Fig3_C.svg', bbox_inches='tight', format='svg')
plt.show()
# Out:
# /tmp/ipykernel_92731/2926049134.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   upsetplot_data_only_activity['Groups_corrected'] = upsetplot_data_only_activity['Groups_corrected'].str.replace('_pval','', regex=False)
# /tmp/ipykernel_92731/2926049134.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   upsetplot_data_only_activity['Groups_corrected'] = upsetplot_data_only_activity['Groups_corrected'].str.split(' & ')
# /home/mmultari/miniconda3/envs/test_run/lib/python3.12/site-packages/upsetplot/data.py:385: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df.fillna(False, inplace=True)
# /home/mmultari/miniconda3/envs/test_run/lib/python3.12/site-packages/upsetplot/plotting.py:795: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   styles["linewidth"].fillna(1, inplace=True)
# /home/mmultari/miniconda3/envs/test_run/lib/python3.12/site-packages/upsetplot/plotting.py:796: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   styles["facecolor"].fillna(self._facecolor, inplace=True)
# /home/mmultari/miniconda3/envs/test_run/lib/python3.12/site-packages/upsetplot/plotting.py:797: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   styles["edgecolor"].fillna(styles["facecolor"], inplace=True)
# /home/mmultari/miniconda3/envs/test_run/lib/python3.12/site-packages/upsetplot/plotting.py:798: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   styles["linestyle"].fillna("solid", inplace=True)

# %%
upset_data
# Out:
#                                                                                             id  \
# Bcinerea Cfulvum Mincognita_7dpi Mincognita_14dpi Pinfestans PSTVd_S23 PSTVd_M
# True     True    True            False            False      False     False    Solyc01g095460
#                                                                        False    Solyc02g062950
#                                  True             True       False     False    Solyc02g077840
#                  False           False            True       True      False    Solyc02g090220
#          False   False           True             False      False     False    Solyc03g093550
#                                  False            False      False     False    Solyc04g008870
#                                                   True       False     False    Solyc04g056310
#                                  True             False      False     False    Solyc04g078770
#                  True            False            False      False     False    Solyc04g078840
#          True    False           False            False      True      True     Solyc05g012500
#          False   False           True             False      False     False    Solyc06g048630
#                  True            True             False      False     False    Solyc06g053350
#          True    True            False            True       True      False    Solyc06g070900
#          False   False           True             False      True      False    Solyc07g054220
#          True    False           False            False      False     False    Solyc07g063420
#          False   True            False            False      False     True     Solyc08g061130
#          True    True            False            True       False     False    Solyc08g081610
#                                                   False      False     False    Solyc10g081350
#          False   False           False            False      False     False    Solyc12g009240
#          True    True            False            False      True      True     Solyc12g014610
# False    True    False           False            False      False     False    Solyc01g102300
#                                                                        False    Solyc01g103050
#                                                                        False    Solyc02g084350
#                                                                        False    Solyc06g051840
#                                  True             True       False     True     Solyc07g066220
#                                  False            True       True      True     Solyc08g006020
#                                                   False      False     False    Solyc08g077110
#          False   True            False            False      False     False    Solyc01g108080
#                                                                        False    Solyc03g026270
#                                                   True       False     False    Solyc03g113760
#                                                   False      False     False    Solyc05g006650
#                                                                        False    Solyc06g071230
#                                                                        True     Solyc07g026680
#                                                                        False    Solyc08g080150
#                                                   True       True      False    Solyc09g010820
#                  False           True             False      False     False    Solyc03g097120
#                                                                        False    Solyc06g065040
#                                                                        False    Solyc12g099370
#                                  False            True       False     False    Solyc04g074170
#                                                                        False    Solyc08g066510
#                                                   False      True      False    Solyc04g072900
#                                                                        True     Solyc12g007180
#
#                                                                                      Family
# Bcinerea Cfulvum Mincognita_7dpi Mincognita_14dpi Pinfestans PSTVd_S23 PSTVd_M
# True     True    True            False            False      False     False           bZIP
#                                                                        False           bZIP
#                                  True             True       False     False            ERF
#                  False           False            True       True      False            Dof
#          False   False           True             False      False     False            ERF
#                                  False            False      False     False            MYB
#                                                   True       False     False            MYB
#                                  True             False      False     False            HSF
#                  True            False            False      False     False           bZIP
#          True    False           False            False      True      True            WRKY
#          False   False           True             False      False     False           bZIP
#                  True            True             False      False     False           bZIP
#          True    True            False            True       True      False            TCP
#          False   False           True             False      True      False            ERF
#          True    False           False            False      False     False            NAC
#          False   True            False            False      False     True            bZIP
#          True    True            False            True       False     False           WRKY
#                                                   False      False     False           bZIP
#          False   False           False            False      False     False            ERF
#          True    True            False            False      True      True            WRKY
# False    True    False           False            False      False     False           bHLH
#                                                                        False            ARF
#                                                                        False            NAC
#                                                                        False            ERF
#                                  True             True       False     True            WRKY
#                                  False            True       True      True             NAC
#                                                   False      False     False            NAC
#          False   True            False            False      False     False           bZIP
#                                                                        False            ERF
#                                                   True       False     False         E2F/DP
#                                                   False      False     False           bHLH
#                                                                        False    MYB_related
#                                                                        True     MYB_related
#                                                                        False            TCP
#                                                   True       True      False            MYB
#                  False           True             False      False     False            HSF
#                                                                        False           bHLH
#                                                                        False           GATA
#                                  False            True       False     False            MYB
#                                                                        False           GATA
#                                                   False      True      False            ERF
#                                                                        True             CPP

# %%
import ast
from collections import defaultdict
TDA_res = pd.read_csv('../Supplementary_Table_4_Details_TFs.tsv', sep='\t')
TDA_res["TDA_Group"] = TDA_res["TDA_Group"].apply(ast.literal_eval)

group_dict = defaultdict(list)

for gene, pos_list in zip(TDA_res["OLN"], TDA_res["TDA_Group"]):
    for pos in pos_list:
        group_dict[pos].append(gene)
        
for megaclust in group_dict.keys():
    if megaclust != 0:
        print(f"Processing Group {megaclust}")
        TF_in_megaclust = group_dict[megaclust]
        upsetplot_data = Tf_info.reset_index()
        upsetplot_data = upsetplot_data[~upsetplot_data['Groups_corrected'].isna()]
        upsetplot_data = upsetplot_data[upsetplot_data['OLN'].isin(TF_in_megaclust)]
        upsetplot_data_only_activity = upsetplot_data[['OLN','Groups_corrected']]
        upsetplot_data_only_activity['Groups_corrected'] = upsetplot_data_only_activity['Groups_corrected'].str.replace('_pval','', regex=False)
        upsetplot_data_only_activity['Groups_corrected'] = upsetplot_data_only_activity['Groups_corrected'].str.split(' & ')
        group_dict_only_acts = {}
        for _, row in upsetplot_data_only_activity.iterrows():
            for group in row['Groups_corrected']:
                if group not in group_dict_only_acts:
                    group_dict_only_acts[group] = []
                group_dict_only_acts[group].append(row['OLN'])
        # Generate the from_contents DataFrame
        upset_data = from_contents(group_dict_only_acts)
        family_tf = Tf_info['Family']
        upset_data = pd.merge(upset_data, family_tf, left_on=['id'], right_index=True)
        if upset_data.shape[0] > 1:
            # Create the UpSet plot
            upset = UpSet(upset_data,  sort_by='-degree', intersection_plot_elements=0)
            upset.style_categories(
                ["Mincognita_7dpi", "Mincognita_14dpi"], bar_facecolor="sienna")
            upset.style_categories(
                ["PSTVd_M", "PSTVd_S23"], bar_facecolor="salmon")
            upset.style_categories(
                ["Bcinerea", "Cfulvum"], bar_facecolor="darkolivegreen")
            upset.style_categories(
                ["Pinfestans"], bar_facecolor="lawngreen")
            upset.add_stacked_bars(by='Family', colors=extended_family_color_dict, elements=5)

            # Plot the UpSet plot
            plot = upset.plot()
            plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left',title='TF Family', title_fontsize=18, fontsize=14)
            plt.title(f'MegaCluster {megaclust}', fontsize=20)    
            plt.savefig(f'./Upsetplot_TF_TDA_group_{megaclust}.svg', bbox_inches='tight', format='svg')
            plt.show()
        else:
            
            print(f"MegaCluster {megaclust} has only one set — showing simple barplot instead of UpSet.")

            # Count TF per family
            family_counts = upset_data['Family'].value_counts()

            # Match each family to its color (fallback to gray if not in dict)
            bar_colors = [extended_family_color_dict.get(fam, "gray") for fam in family_counts.index]

            # Plot barplot
            plt.figure(figsize=(6,4))
            plt.bar(family_counts.index, family_counts.values, color=bar_colors)

            plt.title(f'MegaCluster {megaclust} (single group)', fontsize=16)
            plt.ylabel("TF count", fontsize=14)
            plt.xticks(rotation=45, ha='right')
            plt.tight_layout()
            plt.savefig(f'./Upsetplot_barplot_TF_TDA_group_{megaclust}.svg', bbox_inches='tight', format='svg')
            plt.show()
# Out:
# Processing Group 1
# /tmp/ipykernel_92731/3970990975.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   upsetplot_data_only_activity['Groups_corrected'] = upsetplot_data_only_activity['Groups_corrected'].str.replace('_pval','', regex=False)
# /tmp/ipykernel_92731/3970990975.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   upsetplot_data_only_activity['Groups_corrected'] = upsetplot_data_only_activity['Groups_corrected'].str.split(' & ')
# /home/mmultari/miniconda3/envs/test_run/lib/python3.12/site-packages/upsetplot/data.py:385: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df.fillna(False, inplace=True)
# /home/mmultari/miniconda3/envs/test_run/lib/python3.12/site-packages/upsetplot/plotting.py:795: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   styles["linewidth"].fillna(1, inplace=True)
# /home/mmultari/miniconda3/envs/test_run/lib/python3.12/site-packages/upsetplot/plotting.py:796: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   styles["facecolor"].fillna(self._facecolor, inplace=True)
# /home/mmultari/miniconda3/envs/test_run/lib/python3.12/site-packages/upsetplot/plotting.py:797: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   styles["edgecolor"].fillna(styles["facecolor"], inplace=True)
# /home/mmultari/miniconda3/envs/test_run/lib/python3.12/site-packages/upsetplot/plotting.py:798: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   styles["linestyle"].fillna("solid", inplace=True)
# Processing Group 2
# /tmp/ipykernel_92731/3970990975.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   upsetplot_data_only_activity['Groups_corrected'] = upsetplot_data_only_activity['Groups_corrected'].str.replace('_pval','', regex=False)
# /tmp/ipykernel_92731/3970990975.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   upsetplot_data_only_activity['Groups_corrected'] = upsetplot_data_only_activity['Groups_corrected'].str.split(' & ')
# /home/mmultari/miniconda3/envs/test_run/lib/python3.12/site-packages/upsetplot/data.py:385: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df.fillna(False, inplace=True)
# /home/mmultari/miniconda3/envs/test_run/lib/python3.12/site-packages/upsetplot/plotting.py:795: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   styles["linewidth"].fillna(1, inplace=True)
# /home/mmultari/miniconda3/envs/test_run/lib/python3.12/site-packages/upsetplot/plotting.py:796: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   styles["facecolor"].fillna(self._facecolor, inplace=True)
# /home/mmultari/miniconda3/envs/test_run/lib/python3.12/site-packages/upsetplot/plotting.py:797: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   styles["edgecolor"].fillna(styles["facecolor"], inplace=True)
# /home/mmultari/miniconda3/envs/test_run/lib/python3.12/site-packages/upsetplot/plotting.py:798: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   styles["linestyle"].fillna("solid", inplace=True)
# Processing Group 3
# /tmp/ipykernel_92731/3970990975.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   upsetplot_data_only_activity['Groups_corrected'] = upsetplot_data_only_activity['Groups_corrected'].str.replace('_pval','', regex=False)
# /tmp/ipykernel_92731/3970990975.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   upsetplot_data_only_activity['Groups_corrected'] = upsetplot_data_only_activity['Groups_corrected'].str.split(' & ')
# /home/mmultari/miniconda3/envs/test_run/lib/python3.12/site-packages/upsetplot/data.py:385: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df.fillna(False, inplace=True)
# /home/mmultari/miniconda3/envs/test_run/lib/python3.12/site-packages/upsetplot/plotting.py:795: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   styles["linewidth"].fillna(1, inplace=True)
# /home/mmultari/miniconda3/envs/test_run/lib/python3.12/site-packages/upsetplot/plotting.py:796: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   styles["facecolor"].fillna(self._facecolor, inplace=True)
# /home/mmultari/miniconda3/envs/test_run/lib/python3.12/site-packages/upsetplot/plotting.py:797: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   styles["edgecolor"].fillna(styles["facecolor"], inplace=True)
# /home/mmultari/miniconda3/envs/test_run/lib/python3.12/site-packages/upsetplot/plotting.py:798: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   styles["linestyle"].fillna("solid", inplace=True)
# Processing Group 4
# MegaCluster 4 has only one set — showing simple barplot instead of UpSet.
# /tmp/ipykernel_92731/3970990975.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   upsetplot_data_only_activity['Groups_corrected'] = upsetplot_data_only_activity['Groups_corrected'].str.replace('_pval','', regex=False)
# /tmp/ipykernel_92731/3970990975.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   upsetplot_data_only_activity['Groups_corrected'] = upsetplot_data_only_activity['Groups_corrected'].str.split(' & ')

# %%
# df = signif_tf.reset_index()[['OLN','Family','Groups_corrected']].drop_duplicates()
# df['Groups_corrected']=df['Groups_corrected'].str.replace('_pval','', regex=False)
# # Split the 'Groups_corrected' column into separate conditions by '&' and explode them
# df['Groups_corrected'] = df['Groups_corrected'].str.split('&')
# df_exploded = df.explode('Groups_corrected')

# # Strip extra whitespace
# df_exploded['Groups_corrected'] = df_exploded['Groups_corrected'].str.strip()

# # Count the occurrences of each Family within each Condition
# plot_data = df_exploded.groupby(['Groups_corrected', 'Family']).size().unstack(fill_value=0)

# # Map the family colors to the plot data
# family_colors = plot_data.columns.map(extended_family_color_dict)

# # Create the stacked barplot with custom colors
# ax = plot_data.plot(kind='bar', stacked=True, figsize=(20, 12), color=family_colors)

# ax.spines.top.set_visible(False)
# ax.spines.right.set_visible(False)
# # Set plot labels and title

# plt.xlabel('Condition', fontsize=20)
# plt.ylabel('Number of TF', fontsize = 20)
# plt.xticks(rotation=45, ha='right', fontsize = 18)
# plt.yticks(fontsize = 18)
# ax.set_yticks(range(0, 21, 2))
# plt.legend(title='TF Family', bbox_to_anchor=(1.05, 1), loc='upper left', title_fontsize=20, fontsize=18)
# plt.tight_layout()

# # Show the plot
# # plt.savefig('./Plot/Fig3_B.svg', format='svg')
# plt.show()

# %%
df = signif_tf.reset_index()[['OLN','Family','Groups_corrected']].drop_duplicates()
df['Groups_corrected'] = df['Groups_corrected'].str.replace('_pval', '', regex=False)

# Split the 'Groups_corrected' column into separate conditions by '&' and explode them
df['Groups_corrected'] = df['Groups_corrected'].str.split('&')
df_exploded = df.explode('Groups_corrected')

# Strip extra whitespace
df_exploded['Groups_corrected'] = df_exploded['Groups_corrected'].str.strip()

# Count the occurrences of each Family within each Condition
plot_data = df_exploded.groupby(['Groups_corrected', 'Family']).size().unstack(fill_value=0)

# **Step 1: Compute total TF count per condition**
total_tf_per_condition = plot_data.sum(axis=1)

# **Step 2: Sort conditions by total TF count (ascending)**
sorted_conditions = total_tf_per_condition.sort_values().index

# **Step 3: Reorder plot_data based on sorted conditions**
plot_data = plot_data.loc[sorted_conditions]

# Map the family colors to the plot data
family_colors = plot_data.columns.map(extended_family_color_dict)

# **Step 4: Plot**
ax = plot_data.plot(kind='bar', stacked=True, figsize=(20, 12), color=family_colors)

ax.spines.top.set_visible(False)
ax.spines.right.set_visible(False)

# Set plot labels and title
plt.xlabel('Condition', fontsize=20)
plt.ylabel('Number of TF', fontsize=20)
plt.xticks(rotation=45, ha='right', fontsize=18)
plt.yticks(fontsize=18)
ax.set_yticks(range(0, 21, 2))
plt.legend(title='TF Family', bbox_to_anchor=(1.05, 1), loc='upper left', title_fontsize=20, fontsize=18)
plt.tight_layout()

# Show the plot
plt.savefig('./Fig3_B.svg', format='svg')
plt.show()

# %%
import plotly.graph_objects as go
import pandas as pd
from matplotlib.colors import to_rgba

def sankey_condition_family(df, title="Condition–TF Family Sankey"):
    """
    Sankey plot showing the number of TFs from each family per condition.
    """

    # --- prepare data ---
    df = df.reset_index()[['OLN','Family','Groups_corrected']].drop_duplicates()
    df['Groups_corrected'] = df['Groups_corrected'].str.replace('_pval', '', regex=False)

    # split multiple groups and explode
    df['Groups_corrected'] = df['Groups_corrected'].str.split('&')
    df_exploded = df.explode('Groups_corrected')
    df_exploded['Groups_corrected'] = df_exploded['Groups_corrected'].str.strip()

    # count TFs per condition-family pair
    counts = df_exploded.groupby(['Groups_corrected','Family']).size().reset_index(name="count")

    # --- get sorted unique conditions and families ---
    total_tf_per_condition = counts.groupby("Groups_corrected")["count"].sum().sort_values(ascending=False)
    sorted_conditions = total_tf_per_condition.index.tolist()
    total_tf_per_family = counts.groupby("Family")["count"].sum().sort_values(ascending=False)
    sorted_families = total_tf_per_family.index.tolist()

    # --- node list ---
    cond_labels = [f"{c} ({total_tf_per_condition[c]})" for c in sorted_conditions]
    fam_labels  = [f"{f} ({total_tf_per_family.get(f, 0)})" for f in sorted_families]
    all_nodes = cond_labels + fam_labels
    node_idx = {name: i for i, name in enumerate(all_nodes)}

    # --- build links ---
    links = []
    for _, row in counts.iterrows():
        cond = row["Groups_corrected"]
        fam = row["Family"]
        value = row["count"]

        col = extended_family_color_dict.get(fam, (0.5,0.5,0.5,0.6))  # default grey
        rgba = to_rgba(col)  # ensures proper rgba tuple
        color_str = f"rgba({int(rgba[0]*255)},{int(rgba[1]*255)},{int(rgba[2]*255)},{rgba[3]:.2f})"

        links.append({
            "source": node_idx[f"{cond} ({total_tf_per_condition[cond]})"],
            "target": node_idx[f"{fam} ({total_tf_per_family.get(fam, 0)})"],
            "value": value,
            "color": color_str
        })

     # --- assign fixed positions ---
    n_cond = len(sorted_conditions)
    n_fam = len(sorted_families)
    x_pos, y_pos = [], []

        # left column (conditions)
    for i, _ in enumerate(sorted_conditions):
        x_pos.append(0.001)
        if n_cond > 1:
            y_pos.append((i-0.005) / (n_cond - 1))# evenly spaced top→bottom
        else:
            y_pos.append(0.5)

    # right column (pathways)
    for i, _ in enumerate(sorted_families):
        x_pos.append(0.999)
        if n_fam > 1:
            y_pos.append((i-0.001) / (n_fam - 1))
        else:
            y_pos.append(0.5)
    
    # --- unpack ---
    sources = [l["source"] for l in links]
    targets = [l["target"] for l in links]
    values = [l["value"] for l in links]
    colors = [l["color"] for l in links]

    # --- build figure ---
    fig = go.Figure(data=[go.Sankey(
        arrangement="fixed",
        node=dict(
            pad=60,
            thickness=14,
            line=dict(color="black", width=0.5),
            label=all_nodes,
            color=["rgba(160,160,160,0.9)"]*len(all_nodes),
            x=x_pos,
            y=y_pos
        ),
        link=dict(
            source=sources,
            target=targets,
            value=values,
            color=colors,
            hovertemplate="Condition → TF Family<br>%{source.label} → %{target.label}<br>"
                          "Count: %{value}<extra></extra>"
        )
    )])
    
    fig.update_layout(
        title=title,
        font_size=12,
        margin=dict(l=10, r=10, t=40, b=10),
        width=1200,
        height=1000
    )

    return fig

# %%
fig = sankey_condition_family(signif_tf, title="")
fig.show()

# %%
conditions = ['Pinfestans','Cfulvum','PSTVd_S23','PSTVd_M','Bcinerea','Mincognita_7dpi','Mincognita_14dpi']
expr = 'stats_'
expression = [expr + sample for sample in conditions]
# padj = 'padj_'
# padjs = [padj + sample for sample in conditions]
acts = "_acts"
activity = [sample + acts for sample in conditions]
pval = "_pval"
pvals = [sample + pval for sample in conditions]
Tf_expr = Tf_info[expression]
# TF_padj = Tf_info[padjs]
signif_tf_clusterm = signif_tf.copy()
Tf_activity = Tf_info[activity]
Tf_activity.columns = Tf_activity.columns.str.replace('_acts', '', regex=False)
Tf_pval = Tf_info[pvals]
Tf_activity_signif = Tf_activity[Tf_activity.index.isin(signif_tf.index)]
Tf_activity = Tf_activity.dropna(how='any')
Tf_expr_signif = Tf_expr[Tf_expr.index.isin(Tf_activity.index)]

# %%
# # Step 1: Define sample types based on sample names
# sample_names = Tf_activity.columns  # Assuming this contains your sample names
# sample_types = []

# # Manually define sample types based on your naming convention
# for name in sample_names:
#     if "incognita" in name.lower():
#         sample_types.append("RKN")
#     elif "pstvd" in name.lower():
#         sample_types.append("Virus")
#     elif "infestans" in name.lower():
#         sample_types.append("Oomycete")
#     else:
#         sample_types.append("Fungus")

# # Step 2: Create a color palette for sample types
# sample_type_colors = {
#     "RKN": "sienna",
#     "Virus": "salmon",
#     "Oomycete": "lawngreen",
#     "Fungus": "darkolivegreen"
# }

# # Map the colors based on sample types
# col_colors = [sample_type_colors[sample_types[i]] for i in range(len(sample_types))]

# # Convert col_colors to a DataFrame
# col_colors_df = pd.DataFrame(col_colors, index=sample_names, columns=['Pathogen Type'])

# # Map each gene family in `row_colors` using `color_dict`
# row_colors = Tf_info['Family'].map(extended_family_color_dict)
# # Create the clustermap
# g = sns.clustermap(
#     Tf_activity,
#     cmap=sns.diverging_palette(145, 300, s=60, as_cmap=True),
#     col_cluster=True,
#     row_cluster=True,
#     center=0,
#     cbar_kws={'label': 'TF ULM activity'},
#     method='average',
#     metric='correlation',
#     row_colors=row_colors,
#     col_colors=col_colors_df['Pathogen Type'],
#     figsize=(14, 12),
#     yticklabels=False,
#     vmin=-5,
#     vmax=5
# )

# g.ax_heatmap.set(ylabel="")
# g.ax_row_colors.set_aspect('auto')
# # Retrieve the order of columns after clustering
# ordered_indices = g.dendrogram_col.reordered_ind  # Get the order of columns

# # Overlay sample type labels for each column color
# for idx, ordered_idx in enumerate(ordered_indices):
#     sample_type = sample_types[ordered_idx]  # Get the correct sample type
#     color = sample_type_colors[sample_type]  # Get the corresponding color for the sample type
#     g.ax_col_colors.text(
#         idx + 0.5, 0.5, sample_type, ha='center', va='center', color='black',  # Text color set to black
#         fontsize=8, weight='bold'
#     )

# # Retrieve the order of rows after clustering
# ordered_row_indices = g.dendrogram_row.reordered_ind
# ordered_families = Tf_info['Family'].iloc[ordered_row_indices].values

# # --- Step 1: Create a Legend for TF Families ---
# # Get unique families and their corresponding colors
# unique_families = sorted(set(ordered_families), key=lambda x: list(extended_family_color_dict.keys()).index(x))
# legend_handles = [Patch(facecolor=extended_family_color_dict[fam], label=fam) for fam in unique_families]

# # --- Step 2: Add the Legend to the Figure ---
# plt.legend(handles=legend_handles, title="TF Family", bbox_to_anchor=(0, 0), loc='upper right', fontsize=18, title_fontsize=20, facecolor=None)

# # Save and show the plot
# g.savefig("./Results/Clean_plot/Clustermap_all_tf_acts.svg", bbox_inches='tight', format='svg')
# plt.show()

# %%
# Step 1: Define sample types based on sample names
sample_names = Tf_activity.columns  # Assuming this contains your sample names
sample_types = []

# Manually define sample types based on your naming convention
for name in sample_names:
    if "incognita" in name.lower():
        sample_types.append("RKN")
    elif "pstvd" in name.lower():
        sample_types.append("Virus")
    elif "infestans" in name.lower():
        sample_types.append("Oomycete")
    else:
        sample_types.append("Fungus")

# Step 2: Create a color palette for sample types
sample_type_colors = {
    "RKN": "sienna",
    "Virus": "salmon",
    "Oomycete": "lawngreen",
    "Fungus": "darkolivegreen"
}

# Map the colors based on sample types
col_colors = [sample_type_colors[sample_types[i]] for i in range(len(sample_types))]

# Convert col_colors to a DataFrame
col_colors_df = pd.DataFrame(col_colors, index=sample_names, columns=['Pathogen Type'])

# Map each gene family in `row_colors` using `color_dict`
row_colors = Tf_info['Family'].map(extended_family_color_dict)
# Create the clustermap
g = sns.clustermap(
    Tf_activity,
    cmap=sns.diverging_palette(145, 300, s=60, as_cmap=True),
    col_cluster=True,
    row_cluster=True,
    center=0,
    cbar_kws={'label': 'TF ULM activity'},
    cbar_pos=(0.02,0.8,0.02,0.18),
    method='average',
    metric='correlation',
    row_colors=row_colors,
    col_colors=col_colors_df['Pathogen Type'],
    figsize=(14, 12),
    yticklabels=False,
    vmin=-5,
    vmax=5
)

g.ax_heatmap.set(ylabel="")
g.ax_row_colors.set_aspect('auto')
# Retrieve the order of columns after clustering
ordered_indices = g.dendrogram_col.reordered_ind  # Get the order of columns

# Overlay sample type labels for each column color
for idx, ordered_idx in enumerate(ordered_indices):
    sample_type = sample_types[ordered_idx]  # Get the correct sample type
    color = sample_type_colors[sample_type]  # Get the corresponding color for the sample type
    g.ax_col_colors.text(
        idx + 0.5, 0.5, sample_type, ha='center', va='center', color='black',  # Text color set to black
        fontsize=15, weight='bold'
    )

# Retrieve the order of rows after clustering
ordered_row_indices = g.dendrogram_row.reordered_ind
ordered_families = Tf_info['Family'].iloc[ordered_row_indices].values

# --- Step 1: Create a Legend for TF Families ---
# Get unique families and their corresponding colors
unique_families = sorted(set(ordered_families), key=lambda x: list(extended_family_color_dict.keys()).index(x))
legend_handles = [Patch(facecolor=extended_family_color_dict[fam], label=fam) for fam in unique_families]

# --- Step 2: Add the Legend to the Figure ---
plt.legend(handles=legend_handles, title="TF Family", bbox_to_anchor=(0, 0), loc='upper right', fontsize=18, title_fontsize=20, facecolor=None)

# Save and show the plot
g.savefig("./Clustermap_all_tf_acts.svg", bbox_inches='tight', format='svg')
plt.show()

# %%
# Step 1: Define sample types based on sample names
sample_names = Tf_activity_signif.columns  # Assuming this contains your sample names
sample_types = []

# Manually define sample types based on your naming convention
for name in sample_names:
    if "incognita" in name.lower():
        sample_types.append("RKN")
    elif "pstvd" in name.lower():
        sample_types.append("Virus")
    elif "infestans" in name.lower():
        sample_types.append("Oomycete")
    else:
        sample_types.append("Fungus")

# Step 2: Create a color palette for sample types
sample_type_colors = {
    "RKN": "sienna",
    "Virus": "salmon",
    "Oomycete": "lawngreen",
    "Fungus": "darkolivegreen"
}

# Map the colors based on sample types
col_colors = [sample_type_colors[sample_types[i]] for i in range(len(sample_types))]

# Convert col_colors to a DataFrame
col_colors_df = pd.DataFrame(col_colors, index=sample_names, columns=['Pathogen Type'])

# Map each gene family in `row_colors` using `color_dict`
row_colors = Tf_info['Family'].map(extended_family_color_dict)
# Create the clustermap
g = sns.clustermap(
    Tf_activity_signif,
    cmap=sns.diverging_palette(145, 300, s=60, as_cmap=True),
    col_cluster=True,
    row_cluster=True,
    center=0,
    cbar_kws={'label': 'TF ULM activity'},
    cbar_pos=(0.02,0.8,0.02,0.18),
    method='average',
    metric='correlation',
    row_colors=row_colors,
    col_colors=col_colors_df['Pathogen Type'],
    figsize=(14, 12),
    yticklabels=True,
    vmin=-4,
    vmax=4
)

g.ax_heatmap.set(ylabel="")
g.ax_row_colors.set_aspect('auto')
# Retrieve the order of columns after clustering
ordered_indices = g.dendrogram_col.reordered_ind  # Get the order of columns

# Overlay sample type labels for each column color
for idx, ordered_idx in enumerate(ordered_indices):
    sample_type = sample_types[ordered_idx]  # Get the correct sample type
    color = sample_type_colors[sample_type]  # Get the corresponding color for the sample type
    g.ax_col_colors.text(
        idx + 0.5, 0.5, sample_type, ha='center', va='center', color='black',  # Text color set to black
        fontsize=15, weight='bold'
    )

# Retrieve the order of rows after clustering
ordered_row_indices = g.dendrogram_row.reordered_ind
ordered_families = signif_tf['Family'].iloc[ordered_row_indices].values

# --- Step 1: Create a Legend for TF Families ---
# Get unique families and their corresponding colors
unique_families = sorted(set(ordered_families), key=lambda x: list(extended_family_color_dict.keys()).index(x))
legend_handles = [Patch(facecolor=extended_family_color_dict[fam], label=fam) for fam in unique_families]

# --- Step 2: Add the Legend to the Figure ---
plt.legend(handles=legend_handles, title="TF Family", bbox_to_anchor=(0, 0), loc='upper right', fontsize=18, title_fontsize=20, facecolor=None)

# Save and show the plot
g.savefig("./Fig3_D.svg", bbox_inches='tight', format='svg')
plt.show()

# %%
tf_activity = Tf_info[activity]
tf_activity.fillna(0, inplace=True)
# Out:
# /tmp/ipykernel_92731/751934929.py:2: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
tf_stats = Tf_info[expression]

# %%
from scipy.stats import pearsonr
from matplotlib.lines import Line2D
plt.rcParams['svg.fonttype'] = 'none'
# Create a figure for scatter plots
plt.figure(figsize=(12, 8))

# Define a color palette
color_palette = sns.color_palette("tab10", n_colors=len(tf_activity.columns))
# List to hold legend labels
legend_handles = []

# Loop through the columns of hubs_activity
for i, column in enumerate(tf_activity.columns):
    # Split the column name to get the first two parts
    parts = column.split('_')
    
    # Construct the corresponding column name based on the number of parts
    if len(parts) == 2:
        # For columns with one separator
        corresponding_column = f"stats_{parts[0]}"
    elif len(parts) == 3:
        # For columns with two separators
        corresponding_column = f"stats_{parts[0]}_{parts[1]}"
    else:
        # Skip if the column name doesn't match expected patterns
        print(f"Warning: Unexpected column name format for {column}")
        continue

    # Debugging: Check if the constructed column exists in logfc
    if corresponding_column in tf_stats.columns:  
        x = tf_activity[column]
        y = tf_stats[corresponding_column]
        
        # Define the color for the current group
        color = color_palette[i]
        
        # Calculate the correlation
        if len(x) > 1:
            r, pval = pearsonr(x, y)
            label = f"{column} vs {corresponding_column}\nr = {r:.2f}, p = {pval:.3f}"
        else:
            label = f"{column} vs {corresponding_column}\nr = NA, p = NA"
        
        sns.scatterplot(x=x, y=y, color=color, label=f'{column} vs {corresponding_column}', alpha=0.7,s=50)
        
        # Create the legend label with the correlation value
        legend_handles.append(
            Line2D([0], [0],
                   marker='o',
                   color='w',
                   markerfacecolor=color,
                   markersize=10,
                   label=label)
        )
    else:
        print(f"Warning: {corresponding_column} not found in logfc")

# Customize the plot

plt.xlabel("ULM Activity Values")
plt.ylabel("T stats Values")

# Create the legend with the correlation values
plt.legend(handles=legend_handles, loc='best')

plt.savefig('./Correlation_stats_activity.svg', format='svg')
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from scipy.stats import pearsonr
from matplotlib.lines import Line2D
import pandas as pd
Degree = pd.read_csv('../TDA/Degree_CGRN.tsv', sep='\t', index_col=0)
Degree_total = Degree['Total_Degree']
Activity = pd.read_csv('../TDA/Data/Activity_TF_in_cGRN.tsv', sep='\t', index_col=0)
merged=pd.merge(Degree_total, Activity, left_index=True, right_index=True, how='right')
merged.reset_index(inplace=True)
long_df = pd.melt(merged, id_vars=['Gene_Name','Total_Degree'], var_name='Condition', value_name='Value')

plt.figure(figsize=(12, 8))

# Set color palette for conditions
palette = sns.color_palette("tab10", n_colors=len(long_df['Condition'].unique()))
conditions = long_df['Condition'].unique()

# Dictionary to store correlation info
corr_dict = {}

# Loop through each condition to plot and store Pearson correlation and p-value
for idx, condition in enumerate(conditions):
    # Filter data for the current condition
    subset = long_df[long_df['Condition'] == condition].copy()
    subset['Value'] = abs(subset['Value'])
    
    # Plot scatter and regression line
    sns.scatterplot(
        data=subset,
        x='Total_Degree',
        y='Value',
        color=palette[idx],
        alpha=0.7,
        s=50,
        label=condition  # Add condition as label for the legend
    )
    
    # Calculate Pearson correlation coefficient and p-value
    if len(subset) > 1:  # Ensure there are at least two points to compute correlation
        corr, pval = pearsonr(subset['Total_Degree'], subset['Value'])
        corr_dict[condition] = f"r = {corr:.2f}, p = {pval:.3f}"
    else:
        corr_dict[condition] = "r = NA, p = NA"
    

# Customize the plot

plt.xlabel('Degree of TF in the GRN')
plt.ylabel('Absolute value of TF ULM Activity')
plt.grid(True)

# Create a second legend for correlation coefficients
corr_legend_handles = [
    Line2D([0], [0], marker='o', color='w', markerfacecolor=palette[idx], markersize=10, 
           label=f"{condition}: {corr_dict[condition]}")
    for idx, condition in enumerate(conditions)
]

# Add condition legend (default from seaborn)
# plt.legend(title="Condition", loc="upper left", bbox_to_anchor=(1, 1))  

# Add correlation legend
plt.gca().add_artist(plt.legend(handles=corr_legend_handles, title="Correlation (Pearson)", loc="upper right", bbox_to_anchor=(1, 1)))

# Adjust layout to make space for legends
plt.tight_layout()
plt.savefig('../Plot/Correlation_degree_activity.svg', format='svg')
plt.show()

# %%
subset
# Out:
#           Gene_Name  Total_Degree              Condition     Value
# 426  Solyc01g065540            13  Mincognita_14dpi_acts  0.156054
# 427  Solyc01g087990            17  Mincognita_14dpi_acts  0.628163
# 428  Solyc01g095460            85  Mincognita_14dpi_acts  0.093641
# 429  Solyc01g102300            69  Mincognita_14dpi_acts  1.544044
# 430  Solyc01g103050            12  Mincognita_14dpi_acts  0.195754
# ..              ...           ...                    ...       ...
# 492  Solyc12g009240           172  Mincognita_14dpi_acts  0.522680
# 493  Solyc12g014610            25  Mincognita_14dpi_acts  0.010814
# 494  Solyc12g077540            15  Mincognita_14dpi_acts  0.500244
# 495  Solyc12g056510            11  Mincognita_14dpi_acts  0.512166
# 496  Solyc12g099370            56  Mincognita_14dpi_acts  2.181920
#
# [71 rows x 4 columns]

# %%
info = pd.read_csv('../Results_hubs_activity_stats_shuffle_corrected.tsv', sep='\t')
tda_cluster = pd.read_csv('../TDA/Mapper_node_df.tsv', sep='\t')
tda_cluster.rename(columns={'Value':'Clusters'}, inplace=True)
Res_TDA = pd.merge(info, tda_cluster, left_on='OLN', right_on='Gene')
Res_TDA.rename(columns={'gene.family':'Family'}, inplace=True)
Res_TDA_signif = Res_TDA[~Res_TDA['Groups_corrected'].isna()]
Info=Res_TDA_signif[['OLN','Family','Clusters','Groups_corrected']]
Info['Groups_corrected'] = Info['Groups_corrected'].str.split(' & ')
Info = Info.explode('Groups_corrected')
Info['Groups_corrected'] = Info['Groups_corrected'].str.replace('_pval','', regex=False)
Info_modif = Info.copy()
Info_modif['Groups_corrected']=Info_modif['Groups_corrected'].fillna('Not Significant')
conditions = ['Pinfestans','Cfulvum','PSTVd_S23','PSTVd_M','Bcinerea','Mincognita_7dpi','Mincognita_14dpi']

Tf_acts = pd.read_csv('../TDA/Data/Activity_TF_in_cGRN.tsv', sep='\t', index_col=0)
Tf_acts_with_0 = Tf_acts.copy() 
Tf_acts = Tf_acts.loc[(Tf_acts !=0).any(axis=1)]

Info_modif['Activity_Column'] = Info_modif['Groups_corrected'] + "_acts"

def get_sign(row):
    if row["Groups_spe"] == "Significant":
        gene = row["OLN"]  # Get gene name from the row
        activity_col = row["Activity_Column"]  # Get activity column name
        if gene in Tf_acts.index and activity_col in Tf_acts.columns:
            value = Tf_acts.loc[gene, activity_col]  # Lookup value
            return "POS" if value > 0 else "NEG"
    return "Not Significant"


for condition in conditions:
    Info_modif['Groups_spe']=Info_modif['Groups_corrected'].str.contains(condition)
    Info_modif['Groups_spe']=Info_modif['Groups_spe'].replace({True:'Significant',False:'Not Significant'})
    Info_modif["Sign"] = Info_modif.apply(get_sign, axis=1)
    # Group by MegaCluster, Clusters, and Significance to count the number of TFs
    grouped = Info_modif.groupby(['Clusters', 'Sign']).size().reset_index(name='Count')

    # Create a pivot table for plotting
    pivot = grouped.pivot_table(index='Clusters', columns='Sign', values='Count', fill_value=0)

    custom_order = [0,2,3,5, 7,19, 9,13,15,17,18, 11]
    # Define colors for the plot
    colors = ['gray', 'darkgreen', 'darkorchid']  # List of colors for the 'True' and 'False' categories
    pivot = pivot.loc[custom_order]

    sign_order = ['Not Significant', 'NEG', 'POS']
    pivot = pivot[sign_order]
    # Plot the stacked barplot using seaborn
    ax = pivot.plot(kind='bar', stacked=True, figsize=(10, 6), color=colors)

    # ax.vlines(3.5, *ax.get_ylim(), color='black', linestyle='--')
    # ax.text(1.5, ax.get_ylim()[1] * 1, 'Mega Cluster 1', ha='center', va='center', rotation=0, color='black', fontsize=12)
    # ax.vlines(4.5, *ax.get_ylim(), color='black', linestyle='--')
    # ax.text(4, ax.get_ylim()[1] * 1, 'Mega Cluster 2', ha='center', va='center', rotation=0, color='black', fontsize=12)
    # ax.vlines(10.5, *ax.get_ylim(), color='black', linestyle='--')
    # ax.text(7.5, ax.get_ylim()[1] * 0.9, 'Mega Cluster 3', ha='center', va='center', rotation=0, color='black', fontsize=12)
    # ax.vlines(11.4, *ax.get_ylim(), color='black', linestyle='--')
    # ax.text(11, ax.get_ylim()[1] * 0.9, 'Mega Cluster 4', ha='center', va='center', rotation=0, color='black', fontsize=12)
    # Set plot labels and title
    # plt.title(f'TFs per Cluster by Significance in  {condition}')
    plt.xlabel('Cluster')
    plt.ylabel('Number of TFs')
    plt.xticks(rotation=45, ha='right')
    plt.legend(title='Significance', bbox_to_anchor=(1.05, 1), loc='upper left')
    
    plt.tight_layout()
    plt.savefig(f'../TDA/Plot/Signif_TF_per_cluster_by_significance_in_{condition}.svg', format='svg')
    plt.show()
# Out:
# /tmp/ipykernel_92731/1954961879.py:8: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
custom_cluster = {1: [0,2,3,5],
                  2: [7],
                  3: [9,18,13,15,17,11],
                  4: [19]}
value_to_meta = {v: k for k, vals in custom_cluster.items() for v in vals}

# %%
Res_TDA_signif["TDA_Group"]=Res_TDA_signif['Clusters'].map(value_to_meta)
# Out:
# /tmp/ipykernel_92731/3395936865.py:1: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
result = (
    Res_TDA_signif.dropna(subset=["TDA_Group"])
      .assign(flag=True)
      .pivot_table(index="OLN", columns="TDA_Group", values="flag", fill_value=False)
      .astype(bool)
)

# %%
merge = pd.merge(result,Res_TDA_signif[['OLN','Family','Groups_corrected']].drop_duplicates(), left_index=True, right_on='OLN')
merge.set_index('OLN', inplace=True)

# %%
tda_group_tf_acts = merge[[1.0,2.0,3.0,4.0,'Groups_corrected']]
tda_group_tf_acts['N_Groups_corrected'] = tda_group_tf_acts["Groups_corrected"].str.count('&') + 1
tda_group_tf_acts=tda_group_tf_acts.sort_values('N_Groups_corrected', ascending=False)
tda_group_tf_acts=tda_group_tf_acts.drop(columns="Groups_corrected")

# %%
Res_TDA_signif[['OLN','Family']].drop_duplicates()
# Out:
#                 OLN       Family
# 4    Solyc01g095460         bZIP
# 6    Solyc01g102300         bHLH
# 10   Solyc01g103050          ARF
# 13   Solyc01g108080         bZIP
# 15   Solyc02g062950         bZIP
# 17   Solyc02g077840          ERF
# 19   Solyc02g084350          NAC
# 27   Solyc02g090220          Dof
# 30   Solyc03g026270          ERF
# 32   Solyc03g093550          ERF
# 33   Solyc03g097120          HSF
# 36   Solyc03g113760       E2F/DP
# 40   Solyc04g008870          MYB
# 44   Solyc04g056310          MYB
# 45   Solyc04g072900          ERF
# 46   Solyc04g074170          MYB
# 48   Solyc04g078770          HSF
# 50   Solyc04g078840         bZIP
# 54   Solyc05g006650         bHLH
# 58   Solyc05g012500         WRKY
# 63   Solyc06g048630         bZIP
# 65   Solyc06g051840          ERF
# 66   Solyc06g053350         bZIP
# 67   Solyc06g065040         bHLH
# 73   Solyc06g070900          TCP
# 74   Solyc06g071230  MYB_related
# 81   Solyc07g026680  MYB_related
# 84   Solyc07g054220          ERF
# 85   Solyc07g063420          NAC
# 89   Solyc07g066220         WRKY
# 95   Solyc08g006020          NAC
# 99   Solyc08g061130         bZIP
# 101  Solyc08g066510         GATA
# 102  Solyc08g077110          NAC
# 103  Solyc08g080150          TCP
# 105  Solyc08g081610         WRKY
# 107  Solyc09g010820          MYB
# 115  Solyc10g081350         bZIP
# 121  Solyc12g007180          CPP
# 122  Solyc12g009240          ERF
# 126  Solyc12g014610         WRKY
# 131  Solyc12g099370         GATA

# %%
tda_group_tf_acts
# Out:
#                     1      2      3      4  N_Groups_corrected
# OLN
# Solyc02g077840   True  False  False  False                   5
# Solyc06g070900   True  False  False  False                   5
# Solyc12g014610  False  False   True  False                   5
# Solyc07g066220   True  False  False  False                   4
# Solyc05g012500   True  False  False  False                   4
# Solyc08g006020   True  False  False  False                   4
# Solyc08g081610   True  False  False  False                   4
# Solyc02g090220   True  False  False  False                   4
# Solyc02g062950   True  False  False  False                   3
# Solyc01g095460   True  False  False  False                   3
# Solyc07g054220   True  False  False  False                   3
# Solyc08g061130   True  False  False  False                   3
# Solyc10g081350   True  False  False  False                   3
# Solyc09g010820  False  False   True  False                   3
# Solyc06g053350  False  False   True  False                   3
# Solyc03g093550  False   True  False  False                   2
# Solyc06g048630   True  False  False  False                   2
# Solyc03g113760  False   True  False  False                   2
# Solyc12g007180   True  False  False  False                   2
# Solyc07g063420  False  False   True  False                   2
# Solyc07g026680   True  False  False  False                   2
# Solyc04g078840   True  False  False  False                   2
# Solyc04g078770   True  False  False  False                   2
# Solyc04g056310   True  False  False  False                   2
# Solyc01g102300   True  False  False  False                   1
# Solyc01g103050  False   True  False  False                   1
# Solyc03g026270   True  False  False  False                   1
# Solyc02g084350   True  False  False  False                   1
# Solyc01g108080   True  False  False  False                   1
# Solyc06g051840   True  False  False  False                   1
# Solyc04g008870   True  False  False  False                   1
# Solyc03g097120   True  False  False  False                   1
# Solyc04g074170   True  False  False  False                   1
# Solyc04g072900  False   True  False  False                   1
# Solyc06g071230   True  False  False  False                   1
# Solyc06g065040   True  False  False  False                   1
# Solyc05g006650   True  False  False  False                   1
# Solyc08g066510  False   True  False  False                   1
# Solyc08g077110  False  False   True  False                   1
# Solyc08g080150   True  False  False  False                   1
# Solyc12g009240  False   True   True   True                   1
# Solyc12g099370   True   True  False  False                   1

# %%
Res_TDA_signif[['OLN','Family']].drop_duplicates().set_index('OLN')['Family'].sort_index
# Out:
# <bound method Series.sort_index of OLN
# Solyc01g095460           bZIP
# Solyc01g102300           bHLH
# Solyc01g103050            ARF
# Solyc01g108080           bZIP
# Solyc02g062950           bZIP
# Solyc02g077840            ERF
# Solyc02g084350            NAC
# Solyc02g090220            Dof
# Solyc03g026270            ERF
# Solyc03g093550            ERF
# Solyc03g097120            HSF
# Solyc03g113760         E2F/DP
# Solyc04g008870            MYB
# Solyc04g056310            MYB
# Solyc04g072900            ERF
# Solyc04g074170            MYB
# Solyc04g078770            HSF
# Solyc04g078840           bZIP
# Solyc05g006650           bHLH
# Solyc05g012500           WRKY
# Solyc06g048630           bZIP
# Solyc06g051840            ERF
# Solyc06g053350           bZIP
# Solyc06g065040           bHLH
# Solyc06g070900            TCP
# Solyc06g071230    MYB_related
# Solyc07g026680    MYB_related
# Solyc07g054220            ERF
# Solyc07g063420            NAC
# Solyc07g066220           WRKY
# Solyc08g006020            NAC
# Solyc08g061130           bZIP
# Solyc08g066510           GATA
# Solyc08g077110            NAC
# Solyc08g080150            TCP
# Solyc08g081610           WRKY
# Solyc09g010820            MYB
# Solyc10g081350           bZIP
# Solyc12g007180            CPP
# Solyc12g009240            ERF
# Solyc12g014610           WRKY
# Solyc12g099370           GATA
# Name: Family, dtype: object>

# %%
family_rgb = np.array([family_color_dict[fam] for fam in Res_TDA_signif[['OLN','Family']].drop_duplicates().set_index('OLN').reindex(tda_group_tf_acts.index)['Family']]).reshape(-1, 1, 3)

# Separate the boolean part and numeric part
bool_part = tda_group_tf_acts.drop(columns="N_Groups_corrected")
num_part = tda_group_tf_acts[["N_Groups_corrected"]]

fig, (ax0, ax1, ax2) = plt.subplots(
    ncols=3, figsize=(35, 20),
    gridspec_kw={"width_ratios": [0.3, bool_part.shape[1], 0.5],}
)

ax0.imshow(family_rgb, aspect='auto')
ax0.set_xticks([])
ax0.set_yticks([])
ax0.set_title("TF family")

# Left: green/red heatmap for meta-clusters
sns.heatmap(
    bool_part,
    cmap=sns.color_palette(["red", "green"]),
    cbar=False,
    linewidths=0.5,
    linecolor='gray',
    ax=ax1
)
ax1.set_title("TDA group presence")

meta_colors = sns.color_palette(['lime','yellow','skyblue','coral'])

# Add colored rectangles below each meta cluster
for i, color in enumerate(meta_colors):
    ax1.add_patch(plt.Rectangle((i, bool_part.shape[0]), 1, 1,
                                color=color, transform=ax1.transData, clip_on=False, lw=0, zorder=0))


# Right: side column for n_groups
sns.heatmap(
    num_part,
    cmap="magma_r",
    cbar=True,
    linewidths=0.5,
    linecolor='gray',
    ax=ax2
)
ax2.set_title("Number of conditions")

# Aesthetic tweaks
ax1.set_ylabel("TF")
ax1.set_xlabel("TDA group")
ax2.set_ylabel("")
ax2.set_xlabel("")

plt.tight_layout()
plt.show()
